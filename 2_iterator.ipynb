# %%
l1=[1,2,3,4,5,6,7]
for i in l1:
  print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7

# %%
l2=iter(l1)

# %%
l2

# %%
next(l2)
# Out:
# 1

# %%
next(l2)
# Out:
# 2

# %%
for i in l2:
  print(i)
# Out:
# 3
# 4
# 5
# 6
# 7

# %%
s1="AAFT"
for i in s1:
  print(i)
# Out:
# A
# A
# F
# T

# %%
s2=iter(s1)

# %%
s2

# %%
next(s2)
# Out:
# 'A'

# %%
next(s2)
# Out:
# 'A'
