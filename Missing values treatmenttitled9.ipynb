# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("/content/titanic_train.csv")

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# Age and Cabin have a very high number of missing values
# Embarked has very low number of missing values

# %%
# Deleting Data points with missing values

# %%
df["Age"].head(6)
# Out:
# 0    22.0
# 1    38.0
# 2    26.0
# 3    35.0
# 4    35.0
# 5     NaN
# Name: Age, dtype: float64

# %%
df_drop_del=df.dropna(axis=0)
df_drop_del['Age'].head()
# Out:
# 1     38.0
# 3     35.0
# 6     54.0
# 10     4.0
# 11    58.0
# Name: Age, dtype: float64

# %%
# shape before and after deleting missing values
df_drop_del.shape,df.shape
# Out:
# ((183, 12), (891, 12))

# %%
## isnull with ratio
(df.isnull().sum())/df.shape[0]
# Out:
# PassengerId    0.000000
# Survived       0.000000
# Pclass         0.000000
# Name           0.000000
# Sex            0.000000
# Age            0.198653
# SibSp          0.000000
# Parch          0.000000
# Ticket         0.000000
# Fare           0.000000
# Cabin          0.771044
# Embarked       0.002245
# dtype: float64

# %%
# dropping all columns with missing values
df_drop_col=df.dropna(thresh=500,axis=1)
df_drop_col.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Embarked
# 0      0         A/5 21171   7.2500        S
# 1      0          PC 17599  71.2833        C
# 2      0  STON/O2. 3101282   7.9250        S
# 3      0            113803  53.1000        S
# 4      0            373450   8.0500        S

# %%
df_drop_col.shape,df.shape
# Out:
# ((891, 11), (891, 12))

# %% [markdown]
# A better way to deal with missing values without loss of information

# %%
## Replacing with a new category/value
df['Cabin'].head()
# Out:
# 0     NaN
# 1     C85
# 2     NaN
# 3    C123
# 4     NaN
# Name: Cabin, dtype: object

# %%
df['Cabin'].fillna(value='missing')
# Out:
# 0      missing
# 1          C85
# 2      missing
# 3         C123
# 4      missing
#         ...
# 886    missing
# 887        B42
# 888    missing
# 889       C148
# 890    missing
# Name: Cabin, Length: 891, dtype: object

# %%
df['Age'].fillna(value=999)
# Out:
# 0       22.0
# 1       38.0
# 2       26.0
# 3       35.0
# 4       35.0
#        ...
# 886     27.0
# 887     19.0
# 888    999.0
# 889     26.0
# 890     32.0
# Name: Age, Length: 891, dtype: float64

# %%
# make a copy
df_replace=df.copy()

# replace values
df_replace['Age']=df_replace['Age'].fillna(value=999)

df_replace.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
(df['Cabin'].isnull()).astype('int')
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 886    1
# 887    0
# 888    1
# 889    0
# 890    1
# Name: Cabin, Length: 891, dtype: int64

# %%
df_replace.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# inputting missing values using central tendency

# %%
# finding mean value
mean_age=df['Age'].mean()
mean_age
# Out:
# np.float64(29.69911764705882)

# %%
# making a copy

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
categorical_columns=['Name','Sex','Ticket','Cabin','Embarked']
df[categorical_columns].nunique()
# Out:
# Name        891
# Sex           2
# Ticket      681
# Cabin       147
# Embarked      3
# dtype: int64

# %%
# one-hot encoding
pd.get_dummies(df['Embarked']).head().bool=(1/0)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-29-ad923427c140> in <cell line: 0>()
#       1 # one-hot encoding
# ----> 2 pd.get_dummies(df['Embarked']).head().bool=(1/0)
#
# ZeroDivisionError: division by zero
